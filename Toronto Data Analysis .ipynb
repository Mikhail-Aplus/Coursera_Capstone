# %% [markdown]
# # Task 1

# %% [markdown]
# ## Main Task of the project is  exploring and clustering of the neighborhoods in Toronto.
# ### Task 1 - Getting of data from Web pages and creating of data frame based on it
#
# ### Firstly we import needed libraries...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Getting Data from Internet

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
Data_url = requests.get(url).text
Data=BeautifulSoup(Data_url, 'lxml')

# %% [markdown]
# ### Creating of new DataFrame

# %%
table=Data.find('table')
columns_names = ['PostalCode','Borough','Neighborhood']
df_toronto=pd.DataFrame(columns = columns_names)

# %%
df_toronto
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %%
table_rows = table.find_all('tr')

# %% [markdown]
# ### Searching for new Data columns

# %%
for tr in table_rows:
    row_data=[]
    for td in tr.find_all('td'):
        row_data.append(td.text.strip())
    if len(row_data)==3:
        df_toronto.loc[len(df_toronto)] = row_data

# %%
df_toronto.shape
# Out:
# (180, 3)

# %%
df_toronto.head(10)
# Out:
#   PostalCode           Borough                                  Neighborhood
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5        M6A        North York             Lawrence Manor / Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government
# 7        M8A      Not assigned
# 8        M9A         Etobicoke                              Islington Avenue
# 9        M1B       Scarborough                               Malvern / Rouge

# %% [markdown]
# ### Removing Rows in Borough with "Not Assigned"

# %%
df_toronto=df_toronto[df_toronto['Borough']!='Not assigned']

# %%
df_toronto.shape
# Out:
# (103, 3)

# %%
df_toronto.head(10)
# Out:
#    PostalCode           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5         M6A        North York             Lawrence Manor / Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government
# 8         M9A         Etobicoke                              Islington Avenue
# 9         M1B       Scarborough                               Malvern / Rouge
# 11        M3B        North York                                     Don Mills
# 12        M4B         East York              Parkview Hill / Woodbine Gardens
# 13        M5B  Downtown Toronto                      Garden District, Ryerson

# %% [markdown]
# ###  Rows in Neighbornhood  with "Not Assigned" wits replacing from Borough

# %%
##df_toronto[df_toronto['Neighborhood'] == 'Not assigned'] = df_toronto['Borough']

# %% [markdown]
# ##### No cells in Neighborhood with "Not assigned"!

# %%
df_toronto[df_toronto['Neighborhood'] == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %% [markdown]
# ### Resetting Index

# %%
df_toronto=df_toronto.reset_index(drop=True)
df_toronto.head()
# Out:
#   PostalCode           Borough                                  Neighborhood
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 3        M6A        North York             Lawrence Manor / Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %% [markdown]
# ###  Replacing '/' to ','

# %%
df_toronto['Neighborhood'].head()
# Out:
# 0                                       Parkwoods
# 1                                Victoria Village
# 2                      Regent Park / Harbourfront
# 3               Lawrence Manor / Lawrence Heights
# 4    Queen's Park / Ontario Provincial Government
# Name: Neighborhood, dtype: object

# %%
df_toronto['Neighborhood']=df_toronto['Neighborhood'].str.replace('/',',')

# %%
df_toronto['Neighborhood'].head()
# Out:
# 0                                       Parkwoods
# 1                                Victoria Village
# 2                      Regent Park , Harbourfront
# 3               Lawrence Manor , Lawrence Heights
# 4    Queen's Park , Ontario Provincial Government
# Name: Neighborhood, dtype: object

# %% [markdown]
# # Results

# %%
df_toronto.head(10)
# Out:
#   PostalCode           Borough                                  Neighborhood
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3        M6A        North York             Lawrence Manor , Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 5        M9A         Etobicoke                              Islington Avenue
# 6        M1B       Scarborough                               Malvern , Rouge
# 7        M3B        North York                                     Don Mills
# 8        M4B         East York              Parkview Hill , Woodbine Gardens
# 9        M5B  Downtown Toronto                      Garden District, Ryerson

# %%
df_toronto.shape
# Out:
# (103, 3)
